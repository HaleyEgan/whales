# %% [markdown]
# ## Explore World Port Dataset

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('WorldPortData.csv')
coords = pd.read_csv('CountryCodes_reduced.csv')

# %%
data.head()
# Out:
#   Country Code Port Location         Port Name  \
# 0          ALB        Durres    Port of Durres
# 1          ALB       Sarande   Port of Sarande
# 2          ALB      Shengjin  Port of Shengjin
# 3          ALB         Vlore     Port of Vlore
# 4          DZA       Algiers   Port of Algiers
#
#                    Port Authority  \
# 0           Durres Port Authority
# 1          Sarande Port Authority
# 2         Shengjin Port Authority
# 3  Vlore Drejtoria e Portit Detar
# 4    Entreprise Portuaire d'Alger
#
#                                              Address          Phone  \
# 0  Kapitenerija e Portit\nL Nr 1 Rruga Tregtare\n...   355 52 23115
# 1        Port Office\nSarande Port\nSarande\nAlbania   355 85 25827
# 2                                  Shengjin\nAlbania            NaN
# 3                                            Albania            NaN
# 4  02 Rue d'Angkor\nBP 259\nAlgiers, Gare 259\nAl...  213 21 423614
#
#              Fax 800 Number                   Email              Web Site  \
# 0   355 52 22028        NaN          apd@san.com.al                   NaN
# 1   355 85 25827        NaN                     NaN                   NaN
# 2            NaN        NaN                     NaN                   NaN
# 3            NaN        NaN  porti-vlore@aul.com.al                   NaN
# 4  213 21 423603        NaN   epal@portalger.com.dz  www.portalger.com.dz
#
#         Latitude      Longitude UN/LOCODE             Port Type Port Size
# 0  41° 18' 28" N  19° 27' 17" E     ALDRZ               Seaport     Small
# 1  39° 52' 19" N   20° 0' 20" E     ALSAR  Pier, Jetty or Wharf     Small
# 2  41° 48' 41" N  19° 35' 17" E     ALSHG                Harbor     Small
# 3   40° 28' 7" N  19° 27' 36" E     ALVOA               Seaport     Small
# 4  36° 46' 25" N     3° 4' 2" E     DZALG     Deepwater Seaport     Large

# %%
#length of dataset
#len(data)

# %%
#len(coords)

# %%
#drop duplicates
data = data.drop_duplicates(keep='last')
coords = coords.drop_duplicates(keep='last')

# %%
#len(data)

# %%
#len(coords)

# %%
type(data['Country Code'])
data['Country Code'] = pd.Series(data['Country Code'], dtype="string")
type(data['Country Code'])
# Out:
# pandas.core.series.Series

# %%
coords.head()
# Out:
#           Country Country Code
# 0     Afghanistan          AFG
# 1         Albania          ALB
# 2         Algeria          DZA
# 3  American Samoa          ASM
# 4         Andorra          AND

# %%
#type(coords['Country'])

# %%
#type(coords['Country Code'])

# %%
coords['Country'] = pd.Series(coords['Country'], dtype="string")
type(coords['Country'])
# Out:
# pandas.core.series.Series

# %%
coords['Country Code'] = pd.Series(coords['Country Code'], dtype="string")
type(coords['Country Code'])
# Out:
# pandas.core.series.Series

# %%
#merge coords and data tables on 'Country Code'
#df1.merge(df2, on="column_name", how="left")
#coords.join(data, on='Country Code', how='right')
#pd.merge(data, coords, on='Country Code', how='left')
#data = data.merge(coord, on='Country Code', how='left')
#data.join(coords, on='Country Code', how='left')
#new = data.merge(coords, on='Country Code', how='left')
#new = data.join(coords.set_index('Country Code'), on = 'Country Code', how = 'left')

# %%
#data_reduced = data.drop(['Port Name', 'Port Authority', 'Address', 'Phone', 'Fax', '800 Number', 'Email', 'Web Site', 'Latitude', 'Longitude', 'UN/LOCODE', 'Port Type', 'Port Size'], axis=1)

# %%
#data_reduced.head()
# Out:
#   Country Code Port Location
# 0          ALB        Durres
# 1          ALB       Sarande
# 2          ALB      Shengjin
# 3          ALB         Vlore
# 4          DZA       Algiers

# %%
#data_reduced = data_reduced.rename(columns={"Country Code": "country_code", 'Port Location': 'port_location'})
#data_reduced.head()
# Out:
#   country_code port_location
# 0          ALB        Durres
# 1          ALB       Sarande
# 2          ALB      Shengjin
# 3          ALB         Vlore
# 4          DZA       Algiers

# %%
#coords_new = coords.rename(columns={"Country": "country", "Country Code": "country_code"})
#coords_new.head()
# Out:
#           country country_code
# 0     Afghanistan          AFG
# 1         Albania          ALB
# 2         Algeria          DZA
# 3  American Samoa          ASM
# 4         Andorra          AND

# %%
#merged_data = pd.merge(data_reduced, coords_new, on='country_code', how='left')
#merged_data.head()
# Out:
#   country_code port_location country
# 0          ALB        Durres    <NA>
# 1          ALB       Sarande    <NA>
# 2          ALB      Shengjin    <NA>
# 3          ALB         Vlore    <NA>
# 4          DZA       Algiers    <NA>

# %%
#type(merged_data['country'])
# Out:
# pandas.core.series.Series

# %%
#df2 = pd.DataFrame({'CountryCode' : ['AFG' , 'ALB'], 'CountryName' : ['Afganistan', 'Albania']})

# %%
#df1 = pd.DataFrame({'CountryCode' : ['ALB' , 'ALB'], 'PortLocation' : ['AlbaniaPort1', 'AlbaniaPort2']})

# %%
#df1.merge(df2, how='left', on='CountryCode')
#df1.head()
# Out:
#   CountryCode  PortLocation
# 0         ALB  AlbaniaPort1
# 1         ALB  AlbaniaPort2

# %%
#merge country code and data tables
data = pd.merge(data, coords, on='Country Code', how='left')

# %%
data.head()
# Out:
#   Country Code Port Location         Port Name  \
# 0          ALB        Durres    Port of Durres
# 1          ALB       Sarande   Port of Sarande
# 2          ALB      Shengjin  Port of Shengjin
# 3          ALB         Vlore     Port of Vlore
# 4          DZA       Algiers   Port of Algiers
#
#                    Port Authority  \
# 0           Durres Port Authority
# 1          Sarande Port Authority
# 2         Shengjin Port Authority
# 3  Vlore Drejtoria e Portit Detar
# 4    Entreprise Portuaire d'Alger
#
#                                              Address          Phone  \
# 0  Kapitenerija e Portit\nL Nr 1 Rruga Tregtare\n...   355 52 23115
# 1        Port Office\nSarande Port\nSarande\nAlbania   355 85 25827
# 2                                  Shengjin\nAlbania            NaN
# 3                                            Albania            NaN
# 4  02 Rue d'Angkor\nBP 259\nAlgiers, Gare 259\nAl...  213 21 423614
#
#              Fax 800 Number                   Email              Web Site  \
# 0   355 52 22028        NaN          apd@san.com.al                   NaN
# 1   355 85 25827        NaN                     NaN                   NaN
# 2            NaN        NaN                     NaN                   NaN
# 3            NaN        NaN  porti-vlore@aul.com.al                   NaN
# 4  213 21 423603        NaN   epal@portalger.com.dz  www.portalger.com.dz
#
#         Latitude      Longitude UN/LOCODE             Port Type Port Size  \
# 0  41° 18' 28" N  19° 27' 17" E     ALDRZ               Seaport     Small
# 1  39° 52' 19" N   20° 0' 20" E     ALSAR  Pier, Jetty or Wharf     Small
# 2  41° 48' 41" N  19° 35' 17" E     ALSHG                Harbor     Small
# 3   40° 28' 7" N  19° 27' 36" E     ALVOA               Seaport     Small
# 4  36° 46' 25" N     3° 4' 2" E     DZALG     Deepwater Seaport     Large
#
#   Country
# 0    <NA>
# 1    <NA>
# 2    <NA>
# 3    <NA>
# 4    <NA>

# %%
len(data)
# Out:
# 6045

# %%
#find all unique values for Port Size
data['Port Size'].unique()
# Out:
# array(['Small', 'Large', 'Medium', 'Very Small', 'Very Large'],
#       dtype=object)

# %% [markdown]
# #### Groupings
# - Very Small & Small
# - Medium
# - Large & Very Large

# %%
#find all unique values for Port Type
data['Port Type'].unique()
# Out:
# array(['Seaport', 'Pier, Jetty or Wharf', 'Harbor', 'Deepwater Seaport',
#        'Off-Shore Terminal', 'River Port', 'Ferry', 'Marina',
#        'Waterway Region', 'Port Terminal', 'Canal'], dtype=object)

# %%
#sort out largest ports - large and very large
#largest_ports = data.loc[data['Port Size'] == 'Large']
largest_ports = data.loc[data['Port Size'].isin(['Large', 'Very Large'])]

# %%
largest_ports.sample(10)
# Out:
#      Country Code    Port Location            Port Name  \
# 227           BEL         Brussels     Port of Brussels
# 5437          USA           Boston       Port of Boston
# 2358          ITA  Napoli (Naples)       Port of Napoli
# 798           COL        Cartagena    Port of Cartagena
# 5419          USA         Beaumont     Port of Beaumont
# 4126          RUS      Kaliningrad  Port of Kaliningrad
# 4             DZA          Algiers      Port of Algiers
# 4693          ESP        Tarragona    Port of Tarragona
# 2680          JPN           Nagoya       Port of Nagoya
# 282           BRA          Niteroi      Port of Niteroi
#
#                                      Port Authority  \
# 227                               Port de Bruxelles
# 5437                   Massachusetts Port Authority
# 2358                    Autorita Portuale di Napoli
# 798   Sociedad Portuaria Regional de Cartagena S.A.
# 5419                               Port of Beaumont
# 4126                   Kaliningrad Port Authorities
# 4                      Entreprise Portuaire d'Alger
# 4693               Autoritat Portuaria de Tarragona
# 2680                          Nagoya Port Authority
# 282                                             NaN
#
#                                                 Address             Phone  \
# 227      Place des Armateurs 6\nBruxelles 1000\nBelgium    32 2 420.67.00
# 5437                          Boston, MA\nUnited States      617-946-4422
# 2358         Piazzale Pisacane\nNapoli, NA 80133\nItaly     39 081 206929
# 798   Manga Terminal Maritimo\nCartagena A.A 7954\nC...  (57) (5) 6608071
# 5419  1225 Main Street\nBeaumont, TX 77701\nUnited S...      409-835-5367
# 4126      24, Portvaya Str.\nKaliningrad 236003\nRussia   7 0112 44 43 06
# 4     02 Rue d'Angkor\nBP 259\nAlgiers, Gare 259\nAl...     213 21 423614
# 4693  Passeig de l'Escullera s/n\nTarragona 43004\nS...    34 977 259 400
# 2680  8-21 Irifune 1-chome\nMinato-ku\nNagoya, Aichi...   +81 52 654 7840
# 282   Avenida Feliciano Sodre, n 215\nNiteroi, RJ CE...   55 21 2718 3182
#
#                    Fax    800 Number                            Email  \
# 227     32 2 420.69.74           NaN  portdebruxelles@port.irisnet.be
# 5437               NaN  800-294-2791                              NaN
# 2358     39 081 206888           NaN             info@porto.napoli.it
# 798   (57) (5) 6502239           NaN                              NaN
# 5419      409-835-0512           NaN          info@portofbeaumont.com
# 4126   7 0112 44 45 22           NaN                    scport@ray.ru
# 4        213 21 423603           NaN            epal@portalger.com.dz
# 4693    34 977 225 499           NaN        porttgna@porttarragona.es
# 2680   +81 52 654 7995           NaN           info@port-of-nagoya.jp
# 282    55 21 2620 7563           NaN                              NaN
#
#                              Web Site       Latitude       Longitude  \
# 227    www.portdebruxelles.irisnet.be  50° 53' 10" N    4° 23' 16" E
# 5437           www.massport.com/ports  42° 21' 49" N    71° 2' 12" W
# 2358              www.porto.napoli.it  40° 50' 12" N   14° 16' 27" E
# 798      albatros.puertocartagena.com  10° 24' 12" N   75° 31' 51" W
# 5419           www.portofbeaumont.com   30° 4' 41" N     94° 5' 0" W
# 4126  www.transmarine.ru/PORTINFO.HTM   54° 42' 0" N   20° 27' 31" E
# 4                www.portalger.com.dz  36° 46' 25" N      3° 4' 2" E
# 4693             www.porttarragona.es   41° 5' 39" N    1° 13' 21" E
# 2680            www.port-of-nagoya.jp   35° 2' 42" N  136° 50' 53" E
# 282              www.portosrio.gov.br  22° 52' 45" S    43° 7' 45" W
#
#      UN/LOCODE          Port Type   Port Size Country
# 227      BEBRU         River Port       Large    <NA>
# 5437     USBOS  Deepwater Seaport  Very Large    <NA>
# 2358     ITNAP            Seaport       Large    <NA>
# 798      COCTG            Seaport       Large    <NA>
# 5419     USBPT         River Port       Large    <NA>
# 4126     RUKGD            Seaport       Large    <NA>
# 4        DZALG  Deepwater Seaport       Large    <NA>
# 4693     ESTAR            Seaport       Large    <NA>
# 2680       NaN            Seaport  Very Large    <NA>
# 282      BRNTR            Seaport       Large    <NA>

# %%
len(largest_ports)
# Out:
# 169

# %%
#sort out smallest ports - small and very small
smallest_ports = data.loc[data['Port Size'].isin(['Small', 'Very Small'])]
smallest_ports.sample(10)
# Out:
#      Country Code   Port Location                   Port Name  \
# 482           CAN  Port Dalhousie              Port Dalhousie
# 1204          FIN     Martinniemi         Port of Martinniemi
# 3520          NOR     Nygardsjoen          Nygardsjoen Marina
# 133           AUS          Echuca              Port of Echuca
# 3020          NLD       Harlingen           Port of Harlingen
# 4678          ESP       Santurtzi             Puerto Pesquero
# 2270          ITA          Chioma             Porto di Chioma
# 4369          ESP         Bonanza  Puerto y Muelle de Bonanza
# 4948          TCA      Grand Turk             Grand Turk Port
# 924           DNK        Bandholm              Haven Bandholm
#
#            Port Authority                                            Address  \
# 482                   NaN                                    Ontario\nCanada
# 1204                  NaN                               Martinniemi\nFinland
# 3520                  NaN                 Nygardsjoen, Nordland 8120\nNorway
# 133                   NaN  52 Murray Esplanade Echuca\nVictoria 3564\nAus...
# 3020   Gemeente Harlingen      Postbus 10000\nHarlingen 8860 HA\nNetherlands
# 4678                  NaN                          Santurtzi, Bizkaia\nSpain
# 2270                  NaN                             Chioma, Livorno\nItaly
# 4369                  NaN                        Bonanza, Cadiz 11540\nSpain
# 4948  Maritime Department  Butterfield Square\nProvidenciales\nTurks and ...
# 924                   NaN                                  Bandholm\nDenmark
#
#                 Phone              Fax 800 Number  \
# 482               NaN              NaN        NaN
# 1204              NaN              NaN        NaN
# 3520   +47 990 00 852              NaN        NaN
# 133   +61 3 5482 4248  +61 3 5482 6951        NaN
# 3020    31 517 492222    31 517 492222        NaN
# 4678              NaN              NaN        NaN
# 2270              NaN              NaN        NaN
# 4369              NaN              NaN        NaN
# 4948     649-941-3148     649-941-4213        NaN
# 924               NaN              NaN        NaN
#
#                              Email                          Web Site  \
# 482                            NaN             www.portdalhousie.com
# 1204                           NaN                               NaN
# 3520                post@marina.no                         marina.no
# 133       port@portofechuca.org.au           www.portofechuca.org.au
# 3020  gemeentebestuur@harlingen.nl                  www.harlingen.nl
# 4678                           NaN                               NaN
# 2270                           NaN                               NaN
# 4369                           NaN                               NaN
# 4948         tcimaritime@tciway.tc  www.turksandcaicosislands.gov.tc
# 924                            NaN                               NaN
#
#            Latitude       Longitude UN/LOCODE             Port Type  \
# 482   43° 12' 19" N   79° 15' 44" W       NaN                Harbor
# 1204   65° 13' 0" N    25° 17' 2" E       NaN                Harbor
# 3520   67° 7' 12" N   14° 18' 34" E       NaN                Harbor
# 133     36° 7' 7" S  144° 44' 56" E     AUECH            River Port
# 3020  53° 10' 45" N     5° 25' 5" E     NLHAR               Seaport
# 4678  43° 19' 46" N     3° 1' 38" W       NaN                Marina
# 2270  43° 26' 52" N   10° 22' 44" E       NaN                Harbor
# 4369  36° 48' 14" N    6° 20' 13" W       NaN  Pier, Jetty or Wharf
# 4948   21° 26' 1" N    71° 8' 51" W       NaN  Pier, Jetty or Wharf
# 924   54° 50' 15" N   11° 29' 24" E     DKBDX                Harbor
#
#        Port Size Country
# 482        Small    <NA>
# 1204       Small    <NA>
# 3520       Small    <NA>
# 133   Very Small    <NA>
# 3020       Small    <NA>
# 4678  Very Small    <NA>
# 2270  Very Small    <NA>
# 4369       Small    <NA>
# 4948       Small    <NA>
# 924   Very Small    <NA>

# %%
len(smallest_ports)
# Out:
# 5155

# %%
#sort out mid-size ports 
medium_ports = data.loc[data['Port Size'] == 'Medium']
medium_ports.sample(10)
# Out:
#      Country Code   Port Location                 Port Name  \
# 646           CHN          Dongdu            Port of Dongdu
# 1622          DEU   Wilhelmshaven     Port of Wilhelmshaven
# 5007          GBR         Belfast           Port of Belfast
# 301           BRA      Rio Grande        Port of Rio Grande
# 4155          RUS          Moscow            Port of Moscow
# 2951          MEX      Manzanillo      Puerto de Manzanillo
# 2562          JPN  Higashi-Harima    Port of Higashi-Harima
# 4849          THA         Bangkok           Port of Bangkok
# 642           CHN     Da Chan Bay  Da Chan Bay Terminal One
# 4334          ESP       Algeciras     Port of Algeciras Bay
#
#                                          Port Authority  \
# 646                                                 NaN
# 1622                    Niedersachsen Ports GmbH Co. KG
# 5007                      Belfast Harbour Commissioners
# 301             Superintendencia do Porto de Rio Grande
# 4155                                                NaN
# 2951  Administracion Portuaria Integral de Manzanill...
# 2562                      Higashi-Harima Port Authority
# 4849                          Port Authority of Thiland
# 642                            Da Chan Bay Terminal One
# 4334       Autoridad Portuaria de la Bahia de Algeciras
#
#                                                 Address               Phone  \
# 646                                       Dongdu\nChina                 NaN
# 1622  Niederlassung Wilhelmshaven\nNeckarstrasse 10\...        04421/4800-0
# 5007  Harbour Office\nCorporation Square\nBelfast, N...     44 28 9055 4422
# 301   Av. Honorio Bicalho, S/N\nCP 198\nRio Grande, ...        53 3231-1366
# 4155                                     Moscow\nRussia                 NaN
# 2951  Av. Teniente Azueta No. 9\nCol. Burocrata\nMan...     52 314 331 1400
# 2562  5-10-1 Yamate-dori\nChuo-ku\nKobe, Hyogo 650-8...      81 78 341 7711
# 4849                                  Bangkok\nThailand           2249 7878
# 642   Xi Xiang\nBao An District\nShenzhen 518102\nChina  (86) 755 2902 2888
# 4334  Avda. de la Hispanidad, 2\nAlgeciras, Cadiz 11...     34 956 58 54 00
#
#                      Fax 800 Number                        Email  \
# 646                  NaN        NaN                          NaN
# 1622      04421/4800-599        NaN      wilhelmshaven@nports.de
# 5007     44 28 9055 4411        NaN   info@belfast-harbour.co.uk
# 301         53 3231-1857        NaN    ouvidoria@portosrs.com.br
# 4155                 NaN        NaN                          NaN
# 2951     52 314 331 1400        NaN                          NaN
# 2562      81 78 341 6477        NaN                          NaN
# 4849                 NaN        NaN         patonline@port.co.th
# 642   (86) 755 2902 2828        NaN  commercial@DaChanBayOne.com
# 4334     34 956 58 54 43        NaN                 apba@apba.es
#
#                              Web Site       Latitude       Longitude  \
# 646                               NaN  24° 29' 46" N   118° 4' 53" E
# 1622        www.wilhelmshaven-port.de  53° 31' 48" N     8° 7' 31" E
# 5007        www.belfast-harbour.co.uk  54° 37' 14" N    5° 53' 44" W
# 301               www.portosrs.com.br   32° 3' 22" S    52° 4' 54" W
# 4155                              NaN   55° 51' 0" N   37° 27' 51" E
# 2951  www.puerto-de-manzanillo.com.mx   19° 4' 14" N   104° 18' 5" W
# 2562                              NaN  34° 42' 47" N  134° 49' 54" E
# 4849               www.bkp.port.co.th  13° 41' 45" N   100° 35' 9" E
# 642              www.dachanbayone.com  22° 32' 39" N  113° 51' 23" E
# 4334                      www.apba.es   36° 8' 55" N    5° 23' 58" W
#
#      UN/LOCODE   Port Type Port Size Country
# 646        NaN     Seaport    Medium    <NA>
# 1622     DEWVN     Seaport    Medium    <NA>
# 5007     GBBEL     Seaport    Medium    <NA>
# 301      BRRIG     Seaport    Medium    <NA>
# 4155       NaN  River Port    Medium    <NA>
# 2951     MXZLO     Seaport    Medium    <NA>
# 2562       NaN     Seaport    Medium    <NA>
# 4849     THBKK     Seaport    Medium    <NA>
# 642        NaN     Seaport    Medium    <NA>
# 4334     ESALG     Seaport    Medium    <NA>

# %%
len(medium_ports)
# Out:
# 721

# %%
#save new tables as csv files
largest_ports.to_csv("LargePorts.csv", index=False)
medium_ports.to_csv("MediumPorts.csv", index=False)
smallest_ports.to_csv("SmallPorts.csv", index=False)

# %% [markdown]
# #### Groupings
# - Likely coastal and large vessels
#     - Seaport - Deepwater Seaport - Port Terminal - Off-Shore Terminal
# - Other
#     - River Port - Canal - Waterway Region - Ferry - Pier, Jetty or Wharf - Marina - Harbor (?)

# %%
#Mostly Coastal ports (based on port type description)
Coastal_ports = data.loc[data['Port Type'].isin(['Seaport', 'Deepwater Seaport', 'Port Terminal', 'Off-Shore Terminal', 'Ferry', 'Pier, Jetty or Wharf'])]
print(len(Coastal_ports))
Coastal_ports.sample(10)
# Out:
# 2479
#      Country Code           Port Location               Port Name  \
# 631           CHN                  Binhai          Port of Binhai
# 3642          NOR                Slettvik        Vaernes Ferjekai
# 1436          FRA  Port St Louis du Rhone  Port St Louis du Rhone
# 4465          ESP             Escombreras   Puerto de Escombreras
# 3             ALB                   Vlore           Port of Vlore
# 5397          USA               Ashtabula       Port of Ashtabula
# 249           BRA                Candeias    Dow Quimica Terminal
# 1884          IND                   Dahej           Port of Dahej
# 126           AUS              Crib Point      Port of Crib Point
# 637           CHN                  Chiwan          Port of Chiwan
#
#                                 Port Authority  \
# 631   Binhai Harbour Administration Department
# 3642                                       NaN
# 1436                                       NaN
# 4465          Autoridad Portuaria de Cartagena
# 3               Vlore Drejtoria e Portit Detar
# 5397             Ashtabula City Port Authority
# 249                             Dow Quimica SA
# 1884                    Gujarat Maritime Board
# 126                                        NaN
# 637                      Chiwan Port Authority
#
#                                                 Address             Phone  \
# 631   143 Fudong Zhong Road\nBinhai, Jiangsu 224500\...               NaN
# 3642                   Slettvik, Trondelag 7318\nNorway               NaN
# 1436                     Port St Louis du Rhone\nFrance               NaN
# 4465  Plaza Heroes de Cavite\nCartagena, Murcia 3020...    +34 968 325800
# 3                                               Albania               NaN
# 5397  4717 Main Avenue\nAshtabula, OH 44004\nUnited ...     440-992-7154
# 249   Rodovia Matoim\nRodovia Matoim\nCandeias, BA 4...    55 71 801 1011
# 1884  Sector 10-A, Opp. Air Force Station\nGandhinag...      079-23238346
# 126                               Crib Point\nAustralia               NaN
# 637   c/o China Ocean Shpg Agency\nGangwan Yi Road, ...  86 755 2669 4888
#
#                    Fax  800 Number                   Email  \
# 631                NaN         NaN                     NaN
# 3642               NaN         NaN                     NaN
# 1436               NaN         NaN                     NaN
# 4465    +34 968 325815  www.apc.es        cartagena@apc.es
# 3                  NaN         NaN  porti-vlore@aul.com.al
# 5397               NaN         NaN                     NaN
# 249     55 71 649 5042         NaN                     NaN
# 1884      079-23234703         NaN    gmbad1@sancharnet.in
# 126                NaN         NaN                     NaN
# 637   86 755 2669 4297         NaN                     NaN
#
#                                           Web Site       Latitude  \
# 631                                            NaN  33° 48' 36" N
# 3642                                           NaN  63° 34' 51" N
# 1436                                           NaN  43° 22' 59" N
# 4465                                           NaN   37° 34' 4" N
# 3                                              NaN   40° 28' 7" N
# 5397                     www.ashtabulacityport.com  41° 54' 23" N
# 249   www.dow.com/facilities/lamerica/candeias.htm  12° 47' 21" S
# 1884                              www.gmbports.org  21° 39' 41" N
# 126                                            NaN  38° 21' 45" S
# 637                                            NaN  22° 28' 26" N
#
#            Longitude UN/LOCODE             Port Type   Port Size Country
# 631   120° 27' 38" E     CNBFU  Pier, Jetty or Wharf       Small    <NA>
# 3642    9° 30' 34" E       NaN                 Ferry  Very Small    <NA>
# 1436    4° 49' 38" E     FRPSL               Seaport      Medium    <NA>
# 4465    0° 57' 52" W     ESESC               Seaport      Medium    <NA>
# 3      19° 27' 36" E     ALVOA               Seaport       Small    <NA>
# 5397   80° 47' 47" W     USASF               Seaport       Small    <NA>
# 249    38° 28' 30" W       NaN  Pier, Jetty or Wharf       Small    <NA>
# 1884   72° 33' 45" E     INDAH  Pier, Jetty or Wharf       Small    <NA>
# 126   145° 13' 37" E       NaN  Pier, Jetty or Wharf  Very Small    <NA>
# 637   113° 52' 26" E     CNCWN               Seaport       Large    <NA>

# %%
#Other ports (based on port type description)
Other_ports = data.loc[data['Port Type'].isin(['River Port', 'Canal', 'Waterway Region', 'Marina', 'Harbor'])]
print(len(Other_ports))
Other_ports.sample(10)
# Out:
# 3566
#      Country Code         Port Location                     Port Name  \
# 4383          ESP                 Cadiz                Puerto America
# 1276          FRA              Brigneau                 Port Brigneau
# 4795          SWE              Skutskar              Port of Skutskar
# 5073          GBR            Derbyhaven             Derbyhaven Harbor
# 4122          RUS                 Igrim                 Port of Igrim
# 2234          ITA  Campora San Giovanni  Port of Campora San Giovanni
# 1811          ISL            Djupivogur            Port of Djupivogur
# 671           CHN                 Heihe                 Port of Heihe
# 5103          GBR           Flixborough                 Trent Wharves
# 1798          HUN              Budapest                Port of Csepel
#
#                  Port Authority  \
# 4383                        NaN
# 1276                        NaN
# 4795         Stora Enso Pulp AB
# 5073       Isle of Man Harbours
# 4122                        NaN
# 2234                        NaN
# 1811  Djupivogur Port Authority
# 671        Heihe Port Authority
# 5103      Gunness Wharf Limited
# 1798             Ferroport Kft.
#
#                                                 Address              Phone  \
# 4383  Punta de San Felipe S / N \nCadiz, Cadiz 11004...   +34 856 58 00 02
# 1276                                   Brigneau\nFrance  +33 2 98 39 60 10
# 4795                            Skutskar 814 81\nSweden        46 26 85000
# 5073  Castletown Harbour Office\nThe Quay\nCastletow...   44 0 1624 823549
# 4122  Igrim, Khanty-Mansi Autonomous Okrug 628146\nR...                NaN
# 2234               Campora San Giovanni, Cosenza\nItaly                NaN
# 1811               Port Office\nDjupivogur 750\nIceland           478 8288
# 671   4 Wangsu Street\nHeihe, Heilongjiang 164300\nC...    86 456 822 3841
# 5103  Flixborough, Scunthorpe, North Lincolnshire DN...    44 01724 867691
# 1798       Szabadkikoto ut 5-7\nBudapest H1211\nHungary      36 1 278-4001
#
#                     Fax 800 Number                     Email  \
# 4383                NaN        NaN                       NaN
# 1276  +33 2 98 39 76 54        NaN                       NaN
# 4795        46 26 85015        NaN                       NaN
# 5073   44 0 1624 824339        NaN                       NaN
# 4122                NaN        NaN                       NaN
# 2234                NaN        NaN                       NaN
# 1811           478 8188        NaN  djupivogur@djupivogur.is
# 671                 NaN        NaN                       NaN
# 5103    44 01724 289421        NaN   info@gunnesswharf.co.uk
# 1798      36 1 278-4000        NaN                       NaN
#
#                     Web Site       Latitude       Longitude UN/LOCODE  \
# 4383                     NaN  36° 32' 29" N    6° 16' 57" W       NaN
# 1276                     NaN  47° 46' 58" N    3° 38' 48" W       NaN
# 4795       www.storaenso.com   60° 39' 2" N   17° 23' 45" E     SESSR
# 5073     www.gov.im/harbours   54° 4' 30" N    4° 36' 55" W       NaN
# 4122                     NaN  63° 11' 19" N   64° 24' 10" E       NaN
# 2234                     NaN   39° 3' 18" N    16° 5' 32" E       NaN
# 1811       www.djupivogur.is  64° 39' 38" N   14° 17' 18" W     ISDJU
# 671                      NaN   50° 15' 5" N  127° 31' 38" E     CNHEK
# 5103  www.gunnesswharf.co.uk  53° 36' 24" N    0° 42' 39" W       NaN
# 1798        www.ferroport.hu  47° 26' 37" N    19° 3' 41" E     HUBUD
#
#        Port Type   Port Size Country
# 4383      Marina  Very Small    <NA>
# 1276  River Port  Very Small    <NA>
# 4795      Harbor       Small    <NA>
# 5073      Harbor  Very Small    <NA>
# 4122  River Port       Small    <NA>
# 2234      Harbor       Small    <NA>
# 1811      Harbor       Small    <NA>
# 671   River Port       Small    <NA>
# 5103  River Port       Small    <NA>
# 1798  River Port      Medium    <NA>

# %%
Coastal_ports.to_csv("CoastalPorts.csv", index=False)
Other_ports.to_csv("OtherPorts.csv", index=False)
