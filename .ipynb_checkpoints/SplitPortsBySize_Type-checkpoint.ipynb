# %% [markdown]
# ## Explore World Port Dataset

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('WorldPortData.csv')
coords = pd.read_csv('CountryCodes_reduced.csv')

# %%
data.head()
# Out:
#   Country Code Port Location         Port Name  \
# 0          ALB        Durres    Port of Durres
# 1          ALB       Sarande   Port of Sarande
# 2          ALB      Shengjin  Port of Shengjin
# 3          ALB         Vlore     Port of Vlore
# 4          DZA       Algiers   Port of Algiers
#
#                    Port Authority  \
# 0           Durres Port Authority
# 1          Sarande Port Authority
# 2         Shengjin Port Authority
# 3  Vlore Drejtoria e Portit Detar
# 4    Entreprise Portuaire d'Alger
#
#                                              Address          Phone  \
# 0  Kapitenerija e Portit\nL Nr 1 Rruga Tregtare\n...   355 52 23115
# 1        Port Office\nSarande Port\nSarande\nAlbania   355 85 25827
# 2                                  Shengjin\nAlbania            NaN
# 3                                            Albania            NaN
# 4  02 Rue d'Angkor\nBP 259\nAlgiers, Gare 259\nAl...  213 21 423614
#
#              Fax 800 Number                   Email              Web Site  \
# 0   355 52 22028        NaN          apd@san.com.al                   NaN
# 1   355 85 25827        NaN                     NaN                   NaN
# 2            NaN        NaN                     NaN                   NaN
# 3            NaN        NaN  porti-vlore@aul.com.al                   NaN
# 4  213 21 423603        NaN   epal@portalger.com.dz  www.portalger.com.dz
#
#         Latitude      Longitude UN/LOCODE             Port Type Port Size
# 0  41° 18' 28" N  19° 27' 17" E     ALDRZ               Seaport     Small
# 1  39° 52' 19" N   20° 0' 20" E     ALSAR  Pier, Jetty or Wharf     Small
# 2  41° 48' 41" N  19° 35' 17" E     ALSHG                Harbor     Small
# 3   40° 28' 7" N  19° 27' 36" E     ALVOA               Seaport     Small
# 4  36° 46' 25" N     3° 4' 2" E     DZALG     Deepwater Seaport     Large

# %%
#length of dataset
#len(data)

# %%
#len(coords)

# %%
#drop duplicates
data = data.drop_duplicates(keep='last')
coords = coords.drop_duplicates(keep='last')
data.dropna()
coords.dropna()
# Out:
#                Country Country Code
# 0          Afghanistan          AFG
# 1              Albania          ALB
# 2              Algeria          DZA
# 3       American Samoa          ASM
# 4              Andorra          AND
# ..                 ...          ...
# 251  Wallis and Futuna          WLF
# 252     Western Sahara          ESH
# 253              Yemen          YEM
# 254             Zambia          ZMB
# 255           Zimbabwe          ZWE
#
# [256 rows x 2 columns]

# %%
#len(data)

# %%
#len(coords)

# %%
type(data['Country Code'])
data['Country Code'] = pd.Series(data['Country Code'], dtype="string")
type(data['Country Code'])
# Out:
# pandas.core.series.Series

# %%
coords.head()
# Out:
#           Country Country Code
# 0     Afghanistan          AFG
# 1         Albania          ALB
# 2         Algeria          DZA
# 3  American Samoa          ASM
# 4         Andorra          AND

# %%
#type(coords['Country'])

# %%
#type(coords['Country Code'])

# %%
coords['Country'] = pd.Series(coords['Country'], dtype="string")
type(coords['Country'])
# Out:
# pandas.core.series.Series

# %%
coords['Country Code'] = pd.Series(coords['Country Code'], dtype="string")
type(coords['Country Code'])
# Out:
# pandas.core.series.Series

# %%
#merge coords and data tables on 'Country Code'
#df1.merge(df2, on="column_name", how="left")
#coords.join(data, on='Country Code', how='right')
#pd.merge(data, coords, on='Country Code', how='left')
#data = data.merge(coord, on='Country Code', how='left')
#data.join(coords, on='Country Code', how='left')
#new = data.merge(coords, on='Country Code', how='left')
#new = data.join(coords.set_index('Country Code'), on = 'Country Code', how = 'left')

# %%
data_reduced = data.drop(['Port Name', 'Port Authority', 'Address', 'Phone', 'Fax', '800 Number', 'Email', 'Web Site', 'Latitude', 'Longitude', 'UN/LOCODE', 'Port Type', 'Port Size'], axis=1)

# %%
data_reduced.head()
# Out:
#   Country Code Port Location
# 0          ALB        Durres
# 1          ALB       Sarande
# 2          ALB      Shengjin
# 3          ALB         Vlore
# 4          DZA       Algiers

# %%
data_reduced = data_reduced.rename(columns={"Country Code": "country_code", "Port Location": "port_location"})
data_reduced.head()
# Out:
#   country_code port_location
# 0          ALB        Durres
# 1          ALB       Sarande
# 2          ALB      Shengjin
# 3          ALB         Vlore
# 4          DZA       Algiers

# %%
coords_new = coords.rename(columns={"Country": "country", "Country Code": "country_code"})
coords_new.head()
# Out:
#           country country_code
# 0     Afghanistan          AFG
# 1         Albania          ALB
# 2         Algeria          DZA
# 3  American Samoa          ASM
# 4         Andorra          AND

# %%
merged_data = pd.merge(data_reduced, coords_new, on='country_code', how='left')
merged_data.head()
# Out:
#   country_code port_location country
# 0          ALB        Durres    <NA>
# 1          ALB       Sarande    <NA>
# 2          ALB      Shengjin    <NA>
# 3          ALB         Vlore    <NA>
# 4          DZA       Algiers    <NA>

# %%
type(merged_data['country'])
# Out:
# pandas.core.series.Series

# %%
df2 = pd.DataFrame({'CountryCode' : ['AFG' , 'ALB'], 'CountryName' : ['Afganistan', 'Albania']})

# %%
df1 = pd.DataFrame({'CountryCode' : ['AFG' , 'ALB'], 'PortLocation' : ['AfganistanPort1', 'AlbaniaPort2']})

# %%
df1.merge(df2, how='left', on='CountryCode')
df1.head()
# Out:
#   CountryCode     PortLocation
# 0         AFG  AfganistanPort1
# 1         ALB     AlbaniaPort2

# %%
#merge country code and data tables
data = pd.merge(data, coords, on='Country Code', how='left')

# %%
data.head()
# Out:
#   Country Code Port Location         Port Name  \
# 0          ALB        Durres    Port of Durres
# 1          ALB       Sarande   Port of Sarande
# 2          ALB      Shengjin  Port of Shengjin
# 3          ALB         Vlore     Port of Vlore
# 4          DZA       Algiers   Port of Algiers
#
#                    Port Authority  \
# 0           Durres Port Authority
# 1          Sarande Port Authority
# 2         Shengjin Port Authority
# 3  Vlore Drejtoria e Portit Detar
# 4    Entreprise Portuaire d'Alger
#
#                                              Address          Phone  \
# 0  Kapitenerija e Portit\nL Nr 1 Rruga Tregtare\n...   355 52 23115
# 1        Port Office\nSarande Port\nSarande\nAlbania   355 85 25827
# 2                                  Shengjin\nAlbania            NaN
# 3                                            Albania            NaN
# 4  02 Rue d'Angkor\nBP 259\nAlgiers, Gare 259\nAl...  213 21 423614
#
#              Fax 800 Number                   Email              Web Site  \
# 0   355 52 22028        NaN          apd@san.com.al                   NaN
# 1   355 85 25827        NaN                     NaN                   NaN
# 2            NaN        NaN                     NaN                   NaN
# 3            NaN        NaN  porti-vlore@aul.com.al                   NaN
# 4  213 21 423603        NaN   epal@portalger.com.dz  www.portalger.com.dz
#
#         Latitude      Longitude UN/LOCODE             Port Type Port Size  \
# 0  41° 18' 28" N  19° 27' 17" E     ALDRZ               Seaport     Small
# 1  39° 52' 19" N   20° 0' 20" E     ALSAR  Pier, Jetty or Wharf     Small
# 2  41° 48' 41" N  19° 35' 17" E     ALSHG                Harbor     Small
# 3   40° 28' 7" N  19° 27' 36" E     ALVOA               Seaport     Small
# 4  36° 46' 25" N     3° 4' 2" E     DZALG     Deepwater Seaport     Large
#
#   Country
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
len(data)
# Out:
# 6045

# %%
#find all unique values for Port Size
data['Port Size'].unique()
# Out:
# array(['Small', 'Large', 'Medium', 'Very Small', 'Very Large'],
#       dtype=object)

# %% [markdown]
# #### Groupings
# - Very Small & Small
# - Medium
# - Large & Very Large

# %%
#find all unique values for Port Type
data['Port Type'].unique()
# Out:
# array(['Seaport', 'Pier, Jetty or Wharf', 'Harbor', 'Deepwater Seaport',
#        'Off-Shore Terminal', 'River Port', 'Ferry', 'Marina',
#        'Waterway Region', 'Port Terminal', 'Canal'], dtype=object)

# %%
#sort out largest ports - large and very large
#largest_ports = data.loc[data['Port Size'] == 'Large']
largest_ports = data.loc[data['Port Size'].isin(['Large', 'Very Large'])]

# %%
largest_ports.sample(10)
# Out:
#       index_x Country Code Port Location             Port Name  \
# 2694     2841          JPN       Niihama       Port of Niihama
# 282       306          BRA       Niteroi       Port of Niteroi
# 4693     4890          ESP     Tarragona     Port of Tarragona
# 2842     2989          KOR     Gwangyang     Port of Gwangyang
# 5745     5984          USA       Norfolk       Port of Norfolk
# 878       941          CUB        Havana        Port of Havana
# 4927     5139          TUR      Istanbul      Port of Istanbul
# 3973     4152          POL        Gdynia        Port of Gdynia
# 2627     2774          JPN         Kochi         Port of Kochi
# 4857     5060          THA  Laem Chabang  Port of Laem Chabang
#
#                                          Port Authority  \
# 2694                             Niihama Port Authority
# 282                                                 NaN
# 4693                   Autoritat Portuaria de Tarragona
# 2842  Yeosu Regional Maritime Affairs and Fisheries ...
# 5745                            Virginia Port Authority
# 878            Empresa Terminales Mambisas de La Habana
# 4927                  Turkiye Denizcilik Isletmeleri AS
# 3973                        Port of Gdynia Authority SA
# 2627                               Kochi Port Authority
# 4857                         Port Authority of Thailand
#
#                                                 Address             Phone  \
# 2694  5-1 Ikku-cho, 1-chome\nNiihama City, Ehime 792...    81 89 733 5151
# 282   Avenida Feliciano Sodre, n 215\nNiteroi, RJ CE...   55 21 2718 3182
# 4693  Passeig de l'Escullera s/n\nTarragona 43004\nS...    34 977 259 400
# 2842  335-1 Sujeong-dong\nYeosu City 550-705\nKorea,...      061-650-6000
# 5745  7737 Hampton Blvd.\nNorfolk, VA 23505\nUnited ...      757-440-7000
# 878                                        Havana\nCuba        53 616 655
# 4927  Meclisi Mebusan Cad No 52\nSalipazari\nIstanbu...   90 212 252 2100
# 3973  Rotterdamska 9\nPO BOX 225\nGdynia 81-337\nPoland  +48 58 627 40 02
# 2627  1-2-2 Marunouchi\nKochi City, Kochi 780-8570\n...    81 88 823 1111
# 4857  444 Tarua Road\nKlongtoey\nBangkok 10110\nThai...         2269-3000
#
#                    Fax 800 Number                           Email  \
# 2694               NaN        NaN                             NaN
# 282    55 21 2620 7563        NaN                             NaN
# 4693    34 977 225 499        NaN       porttgna@porttarragona.es
# 2842      061-654-2358        NaN                ohkt@momaf.go.kr
# 5745      757-440-2640        NaN                             NaN
# 878         53 338 111        NaN                             NaN
# 4927   90 212 244 3480        NaN  istanbul.liman@superonline.com
# 3973  +48 58 620 31 91        NaN                             NaN
# 2627    81 88 823 9896        NaN     175201@ken.pref.kochi.lg.jp
# 4857         2672-7156        NaN            patonline@port.co.th
#
#                   Web Site       Latitude       Longitude UN/LOCODE  \
# 2694                   NaN  33° 58' 15" N  133° 15' 54" E     JPIHA
# 282   www.portosrio.gov.br  22° 52' 45" S    43° 7' 45" W     BRNTR
# 4693  www.porttarragona.es   41° 5' 39" N    1° 13' 21" E     ESTAR
# 2842        www.portgy.com  34° 53' 18" N  127° 40' 43" E     KRKAN
# 5745       www.vaports.com   36° 54' 7" N   76° 17' 52" W     USORF
# 878                    NaN   23° 7' 57" N   82° 20' 31" W       NaN
# 4927        www.tdi.com.tr   41° 0' 46" N   28° 59' 57" E     TRIST
# 3973    www.port.gdynia.pl   54° 32' 0" N   18° 32' 29" E     PLGDY
# 2627  www.pref.kochi.lg.jp  33° 31' 27" N  133° 33' 40" E     JPKCZ
# 4857        www.port.co.th   13° 4' 26" N  100° 53' 43" E     THLCH
#
#               Port Type   Port Size  index_y Country
# 2694            Seaport       Large      NaN    <NA>
# 282             Seaport       Large      NaN    <NA>
# 4693            Seaport       Large      NaN    <NA>
# 2842            Seaport       Large      NaN    <NA>
# 5745  Deepwater Seaport  Very Large      NaN    <NA>
# 878             Seaport       Large      NaN    <NA>
# 4927  Deepwater Seaport  Very Large      NaN    <NA>
# 3973            Seaport       Large      NaN    <NA>
# 2627  Deepwater Seaport  Very Large      NaN    <NA>
# 4857            Seaport       Large      NaN    <NA>

# %%
len(largest_ports)
# Out:
# 169

# %%
#sort out smallest ports - small and very small
smallest_ports = data.loc[data['Port Size'].isin(['Small', 'Very Small'])]
smallest_ports.sample(10)
# Out:
#       index_x Country Code  Port Location             Port Name  \
# 3058     3214          NZL   New Plymouth         Port Taranaki
# 474       507          CAN  Pointe-au-Pic  Pointe-au-Pic Harbor
# 1001     1070          DNK        Nakskov       Port of Nakskov
# 1964     2087          IDN           Bima         Bima Terminal
# 1359     1443          FRA      La Ciotat     Port of La Ciotat
# 4113     4301          RUS     Dzerzhinsk    Port of Dzerzhinsk
# 982      1051          DNK       Kongsdal         Kongsdal Havn
# 4116     4304          RUS       Gaz-Sale      Port of Gaz-Sale
# 3913     4092          PHL        Calapan      Calapan Terminal
# 3628     3792          NOR           Skei         Skei fergekai
#
#                                Port Authority  \
# 3058                    Port Taranaki Limited
# 474                                       NaN
# 1001                                      NaN
# 1964                                      NaN
# 1359              Port Authority of La Ciotat
# 4113                                      NaN
# 982                                       NaN
# 4116                                      NaN
# 3913  Philippine Ports Authority, PMO Calapan
# 3628                                      AtB
#
#                                                 Address             Phone  \
# 3058  Breakwater Road\nPO Box 348\nNew Plymouth 4340...      64 6 7510200
# 474                               Pointe-au-Pic\nCanada               NaN
# 1001                              Nakskov 4900\nDenmark    45 54 97 03 30
# 1964                                    Bima\nIndonesia               NaN
# 1359           Bassin Berouard\nLa Ciotat 13600\nFrance  33 4 42 08 62 90
# 4113                                 Dzerzhinsk\nRussia               NaN
# 982                                   Kongsdal\nDenmark      45 9858 3727
# 4116  Gaz-Sale, Yamalo-Nenets Autonomous Okrug 62936...               NaN
# 3913   San Antonio\nPort Area\nCalapan City\nPhilipp...     043 439-05-20
# 3628                Fv562\nLeka, Trondelag 7994\nNorway               NaN
#
#                    Fax 800 Number                    Email  \
# 3058      64 6 7510886        NaN  westgate@westgate.co.nz
# 474                NaN        NaN                      NaN
# 1001    45 54 92 51 13        NaN           hab@nakskov.dk
# 1964               NaN        NaN                      NaN
# 1359  33 4 42 71 46 01        NaN                      NaN
# 4113               NaN        NaN                      NaN
# 982       45 8818 1397        NaN     hansaage@webspeed.dk
# 4116               NaN        NaN                      NaN
# 3913     043 288-61-87        NaN    pmocalapan@dalcan.com
# 3628               NaN        NaN                      NaN
#
#                        Web Site       Latitude       Longitude UN/LOCODE  \
# 3058     www.porttaranaki.co.nz   39° 3' 26" S   174° 2' 25" E     NZNPL
# 474                         NaN  47° 37' 22" N    70° 8' 27" W     CAPPC
# 1001                        NaN  54° 49' 56" N    11° 7' 25" E     DKNAK
# 1964                        NaN    5° 46' 0" S   107° 4' 59" E     IDBMT
# 1359                        NaN  43° 10' 15" N    5° 36' 41" E     FRLCT
# 4113                        NaN  56° 13' 36" N   43° 27' 55" E       NaN
# 982   www.kongsdal-baadelaug.dk   56° 41' 2" N    10° 4' 17" E       NaN
# 4116                        NaN  67° 22' 12" N    79° 0' 34" E       NaN
# 3913             www.ppa.com.ph  13° 25' 42" N  121° 11' 39" E       NaN
# 3628              www.atb.no/en   65° 5' 15" N   11° 44' 16" E       NaN
#
#                  Port Type   Port Size  index_y Country
# 3058               Seaport       Small      NaN    <NA>
# 474                 Harbor  Very Small      NaN    <NA>
# 1001               Seaport       Small      NaN    <NA>
# 1964    Off-Shore Terminal  Very Small      NaN    <NA>
# 1359                Harbor       Small      NaN    <NA>
# 4113            River Port  Very Small      NaN    <NA>
# 982                 Harbor       Small      NaN    <NA>
# 4116            River Port       Small      NaN    <NA>
# 3913  Pier, Jetty or Wharf       Small      NaN    <NA>
# 3628                 Ferry  Very Small      NaN    <NA>

# %%
len(smallest_ports)
# Out:
# 5155

# %%
#sort out mid-size ports 
medium_ports = data.loc[data['Port Size'] == 'Medium']
medium_ports.sample(10)
# Out:
#       index_x Country Code   Port Location               Port Name  \
# 4539     4736          ESP          Malaga          Port of Malaga
# 5822     6061          USA        Portland        Port of Portland
# 1622     1715          DEU   Wilhelmshaven   Port of Wilhelmshaven
# 2505     2643          JAM        Kingston        Port of Kingston
# 3833     3997          PAN          Balboa          Port of Balboa
# 2849     2996          KOR      Pyeongtaek      Port of Pyeongtaek
# 5131     5352          GBR  Great Yarmouth  Port of Great Yarmouth
# 247       271          BRA           Belem           Port of Belem
# 2946     3102          MEX         Guaymas       Puerto de Guaymas
# 4412     4609          ESP       Cartagena     Puerto de Cartagena
#
#                                          Port Authority  \
# 4539                      Autoridad Portuaria de Malaga
# 5822                                                NaN
# 1622                    Niedersachsen Ports GmbH Co. KG
# 2505                          Port Authority of Jamaica
# 3833                         Panama Ports Company (PPC)
# 2849  Pyeongtaek Regional Maritime Affairs and Fishe...
# 5131                      Great Yarmouth Port Authority
# 247      Companhia Docas do Para - Autoridade Portuaria
# 2946  Administracion Portuaria Integral de Guaymas, ...
# 4412                   Autoridad Portuaria de Cartagena
#
#                                                 Address           Phone  \
# 4539  Muelle de Canovas, s/n\nMalaga, Malaga 29001\n...  34 952 125 000
# 5822  121 NW Everett Street\nPortland, OR 97209-4049...    503.944.7000
# 1622  Niederlassung Wilhelmshaven\nNeckarstrasse 10\...    04421/4800-0
# 2505               15-17 Duke Street\nKingston\nJamaica  876 922-0290-8
# 3833  Arnulfo Arias Madrid Avenue, Building 1501\nP....    507-207 5100
# 2849  566 Manho-Ii Poseung-myun\nPyeongtaek, Gyeongg...  82-31-683-0313
# 5131  20-21 South Quay\nGreat Yarmouth, Norfolk NR30...  44 1493 335500
# 247   Endereco Av. Marechal Hermes s/n\nCais do Port...    91 3216-2129
# 2946  Recinto portuario, zona franca S/N\nCol. Punta...   622 225-22-50
# 4412  Plaza Heroes de Cavite\nCartagena, Murcia 3020...  +34 968 325800
#
#                  Fax    800 Number                         Email  \
# 4539  34 952 125 002           NaN          sac@puertomalaga.com
# 5822    503.944.7080  800.547.8411  ContactUs@PortofPortland.com
# 1622  04421/4800-599           NaN       wilhelmshaven@nports.de
# 2505    876 924-9437           NaN               paj@portjam.com
# 3833    507-232 5697           NaN               info@ppc.com.pa
# 2849  82-31-680-7219           NaN                           NaN
# 5131  44 1493 852480           NaN      Administrator@gypa.co.uk
# 247     91 3216-2130           NaN            evandro@cdp.com.br
# 2946   622 225-22-50           NaN                           NaN
# 4412  +34 968 325815           NaN              cartagena@apc.es
#
#                        Web Site       Latitude       Longitude UN/LOCODE  \
# 4539       www.puertomalaga.com  36° 42' 33" N     4° 25' 9" W     ESAGP
# 5822   www.portofportlandor.com  45° 36' 21" N   122° 47' 2" W     USPDX
# 1622  www.wilhelmshaven-port.de  53° 31' 48" N     8° 7' 31" E     DEWVN
# 2505            www.portjam.com  17° 58' 54" N   76° 49' 46" W     JMKIN
# 3833             www.ppc.com.pa   8° 57' 20" N   79° 34' 12" W     PABLB
# 2849            www.momaf.go.kr  36° 59' 34" N  126° 47' 31" E     KRPTK
# 5131             www.gypa.co.uk  52° 35' 26" N    1° 43' 46" E     GBGTY
# 247              www.cdp.com.br    1° 27' 6" S    48° 29' 8" W     BRBEL
# 2946    www.puertodeguaymas.com  27° 55' 13" N  110° 52' 35" W     MXGYM
# 4412                 www.apc.es  37° 35' 43" N     0° 59' 8" W     ESCAR
#
#                  Port Type Port Size  index_y Country
# 4539               Seaport    Medium      NaN    <NA>
# 5822            River Port    Medium      NaN    <NA>
# 1622               Seaport    Medium      NaN    <NA>
# 2505               Seaport    Medium      NaN    <NA>
# 3833               Seaport    Medium      NaN    <NA>
# 2849               Seaport    Medium      NaN    <NA>
# 5131               Seaport    Medium      NaN    <NA>
# 247   Pier, Jetty or Wharf    Medium      NaN    <NA>
# 2946               Seaport    Medium      NaN    <NA>
# 4412               Seaport    Medium      NaN    <NA>

# %%
len(medium_ports)
# Out:
# 721

# %%
#save new tables as csv files
largest_ports.to_csv("LargePorts.csv", index=False)
medium_ports.to_csv("MediumPorts.csv", index=False)
smallest_ports.to_csv("SmallPorts.csv", index=False)

# %% [markdown]
# #### Groupings
# - Likely coastal and large vessels
#     - Seaport - Deepwater Seaport - Port Terminal - Off-Shore Terminal
# - Other
#     - River Port - Canal - Waterway Region - Ferry - Pier, Jetty or Wharf - Marina - Harbor (?)

# %%
#Mostly Coastal ports (based on port type description)
Coastal_ports = data.loc[data['Port Type'].isin(['Seaport', 'Deepwater Seaport', 'Port Terminal', 'Off-Shore Terminal', 'Ferry', 'Pier, Jetty or Wharf'])]
print(len(Coastal_ports))
Coastal_ports.sample(10)
# Out:
# 2479
#       index_x Country Code   Port Location                Port Name  \
# 2617     2764          JPN           Kiire            Port of Kiire
# 5183     5404          GBR           Leith            Port of Leith
# 5534     5773          USA        Escanaba         Port of Escanaba
# 3906     4085          PHL        Batangas         Port of Batangas
# 1105     1174          EGY     El-Dekheila      Port of El-Dekheila
# 3941     4120          PHL         Masbate          Port of Masbate
# 2841     2988          KOR          Gunsan  Port of Gunsan (Kunsan)
# 3720     3884          NOR  Svartisen Gard         Svartisen Marina
# 3010     3166          NLD         Alkmaar          Port of Alkmaar
# 4847     5050          THA     Ban Ao Udom      Port of Ban Ao Udom
#
#                                          Port Authority  \
# 2617                               Kiire Port Authority
# 5183                                    Forth Ports PLC
# 5534                                   City of Escanaba
# 3906           Philippine Ports Authority, PMO Batangas
# 1105                          Alexandria Port Authority
# 3941            Philippine Ports Authority, PMO Legaspi
# 2841  Gunsan Regional Maritime Affairs and Fisheries...
# 3720                                                NaN
# 3010                                   Gemeente Alkmaar
# 4847                                                NaN
#
#                                                 Address            Phone  \
# 2617  Ibusuki Public Works Office\n301 Takanohara, 1...    81 993 222171
# 5183  Leith Port Office\nImperial House,  Albert Doc...  44 131 555 8750
# 5534      PO Box 948\nEscanaba, MI 49829\nUnited States     906-786-9614
# 3906        Sta. Clara\nBatangas City 4200\nPhilippines     043 723-1701
# 1105               106 El Horreya St\nAlexandria\nEgypt      203-4458395
# 3941          Pier Site\nLegaspi City 4500\nPhilippines     052 482-0303
# 2841  1530-5 Soryong-dong\nGunsan-si, Jeollabuk-do 5...   82-63-441-2222
# 3720     Hamnhaugveien 60\nOrnes, Nordland 8150\nNorway   +47 909 72 218
# 3010  Public Works Department\nMallegatsplein 10\nAl...   31 72 548 8888
# 4847                              Ban Ao Udom\nThailand              NaN
#
#                   Fax    800 Number                              Email  \
# 2617              NaN           NaN                                NaN
# 5183  44 131 555 1212           NaN  david.macpherson@forthports.co.uk
# 5534     906-789-3798  800-700-9614                                NaN
# 3906     043 723-0164           NaN                     ctf@ppa.com.ph
# 1105      203-4458397           NaN                                NaN
# 3941              NaN           NaN           ppalegs@globalink.net.ph
# 2841   82-63-441-2351           NaN                                NaN
# 3720              NaN           NaN                                NaN
# 3010   31 72 548 8777           NaN                                NaN
# 4847              NaN           NaN                                NaN
#
#                    Web Site       Latitude       Longitude UN/LOCODE  \
# 2617                    NaN  31° 23' 20" N  130° 32' 56" E     JPKII
# 5183   www.forthports.co.uk  55° 58' 57" N    3° 10' 29" W     GBLEI
# 5534                    NaN  45° 45' 27" N    87° 3' 21" W     USESC
# 3906         www.ppa.com.ph  13° 44' 51" N   121° 0' 44" E       NaN
# 1105         www.mts.gov.eg   31° 8' 30" N   29° 47' 56" E       NaN
# 3941         www.ppa.com.ph   12° 22' 5" N  123° 37' 18" E     PHMBT
# 2841  gunsan.mltm.go.kr/eng  35° 57' 35" N  126° 35' 27" E     KRKUV
# 3720                    NaN  66° 42' 35" N   13° 42' 31" E       NaN
# 3010                    NaN  52° 37' 44" N    4° 45' 27" E     NLALK
# 4847                    NaN   13° 7' 21" N  100° 53' 42" E       NaN
#
#                  Port Type   Port Size  index_y Country
# 2617               Seaport      Medium      NaN    <NA>
# 5183               Seaport       Large      NaN    <NA>
# 5534               Seaport       Small      NaN    <NA>
# 3906               Seaport      Medium      NaN    <NA>
# 1105               Seaport  Very Small      NaN    <NA>
# 3941  Pier, Jetty or Wharf       Small      NaN    <NA>
# 2841               Seaport       Large      NaN    <NA>
# 3720  Pier, Jetty or Wharf  Very Small      NaN    <NA>
# 3010                 Ferry       Small      NaN    <NA>
# 4847               Seaport       Small      NaN    <NA>

# %%
#Other ports (based on port type description)
Other_ports = data.loc[data['Port Type'].isin(['River Port', 'Canal', 'Waterway Region', 'Marina', 'Harbor'])]
print(len(Other_ports))
Other_ports.sample(10)
# Out:
# 3566
#       index_x Country Code Port Location            Port Name  \
# 5382     5621          USA      Alliance     Port of Alliance
# 4934     5146          TUR       Mudanya      Port of Mudanya
# 5735     5974          USA      Newburgh     Port of Newburgh
# 3294     3458          NOR       Helland       Helland Marina
# 667       718          CHN      Hangzhou     Port of Hangzhou
# 401       434          CAN       Godbout      Port of Godbout
# 4576     4773          ESP    Palamos       Marina de Palamos
# 5664     5903          USA      Longview     Port of Longview
# 5938     6177          USA    West Point  Port of Clay County
# 2237     2375          ITA      Capitana   Marina Di Capitana
#
#               Port Authority  \
# 5382                     NaN
# 4934  Mudanya Port Authority
# 5735        City of Newburgh
# 3294                     NaN
# 667                      NaN
# 401          Port of Godbout
# 4576                     NaN
# 5664                     NaN
# 5938      Tom Soya Grain Co.
# 2237                     NaN
#
#                                                 Address             Phone  \
# 5382                        Alliance, LA\nUnited States               NaN
# 4934                  Liman Baskanligi\nMudanya\nTurkey   90 224 544 1650
# 5735     83 Broadway\nNewburgh, NY 12550\nUnited States      845-569-7300
# 3294              Helland, More og Romsdal 6390\nNorway               NaN
# 667                                     Hangzhou\nChina               NaN
# 401   PO Box 520\n1410 Rue Matane sur Mer\nMatane, Q...      418 562 2500
# 4576  Carrer Salvador Albert i Pey, 0\nPalamos   , G...  +34 972 60 10 00
# 5664  10 Port Way\nP.O. Box 1258\nLongview, WA 98632...    (360) 425-3305
# 5938  11018 Old Highway 50\nWest Point, MS 39773\nUn...  662 494-3754 x24
# 2237                                    Capitana\nItaly         070805460
#
#                     Fax 800 Number                         Email  \
# 5382                NaN        NaN                           NaN
# 4934    90 224 544 1657        NaN        mudanya@mudanya.bel.tr
# 5735                NaN        NaN                           NaN
# 3294                NaN        NaN                           NaN
# 667                 NaN        NaN                           NaN
# 401        418 560 8013        NaN    stq@traversiers.gouv.qc.ca
# 4576  +34 972 60 22 66         NaN        info@marinapalamos.com
# 5664     (360) 425-8650        NaN  marketing@portoflongview.com
# 5938       662 494-3759        NaN       plucas@tomsoyagrain.com
# 2237                NaN        NaN                           NaN
#
#                     Web Site       Latitude      Longitude UN/LOCODE  \
# 5382                     NaN  29° 40' 52" N  89° 58' 16" W       NaN
# 4934                     NaN  40° 22' 37" N  28° 52' 51" E     TRMUD
# 5735     www.newburgh-ny.com  41° 29' 27" N   74° 0' 27" W       NaN
# 3294                     NaN  62° 37' 19" N    7° 5' 45" E       NaN
# 667                      NaN   30° 17' 1" N  120° 9' 42" E     CNHGH
# 401                      NaN  49° 19' 22" N  67° 35' 23" W     CAGBT
# 4576   www.marinapalamos.com  41° 50' 44" N     3° 8' 5" E       NaN
# 5664  www.portoflongview.com   46° 6' 46" N  122° 58' 2" W     USLOG
# 5938    www.tomsoyagrain.com  33° 34' 37" N  88° 29' 36" W       NaN
# 2237                     NaN  39° 12' 22" N   9° 18' 10" E       NaN
#
#        Port Type   Port Size  index_y Country
# 5382  River Port       Small      NaN    <NA>
# 4934      Harbor       Small      NaN    <NA>
# 5735  River Port       Small      NaN    <NA>
# 3294      Marina  Very Small      NaN    <NA>
# 667   River Port       Small      NaN    <NA>
# 401       Harbor       Small      NaN    <NA>
# 4576      Marina       Small      NaN    <NA>
# 5664  River Port       Small      NaN    <NA>
# 5938  River Port  Very Small      NaN    <NA>
# 2237      Marina  Very Small      NaN    <NA>

# %%
Coastal_ports.to_csv("CoastalPorts.csv", index=False)
Other_ports.to_csv("OtherPorts.csv", index=False)
